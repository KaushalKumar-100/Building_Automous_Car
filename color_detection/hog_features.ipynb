# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib.image as mpimg
from skimage.feature import hog

# %%
image=cv2.imread("truck_free_s.jpg")
cv2.imshow("truck_image",image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
image_g=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(image_g,cmap='gray')

# %%
x_sobel=cv2.Sobel(image_g,cv2.CV_64F,0,1,ksize=7)
cv2.imshow("truck_image",x_sobel)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
y_sobel=cv2.Sobel(image_g,cv2.CV_64F,1,0,ksize=7)
cv2.imshow("truck_image",y_sobel)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# Perform Histogram Gradient Orientation

# %%
features,hog_image=hog(image_g,
                       orientations=9,
                       pixels_per_cell=(16,16),
                       cells_per_block=(1,1),
                       transform_sqrt=False,
                       visualize=True,
                       feature_vector=False
                       )
features.shape
# Out:
# (42, 59, 1, 1, 9)

# %%
features[30,50,]
# Out:
# array([[[0.62049729, 0.25487372, 0.07395602, 0.16299491, 0.15378672,
#          0.18936363, 0.13930874, 0.2324928 , 0.62049729]]])

# %%
hog_image.shape
# Out:
# (678, 957)

# %%
from skimage import exposure
hog_image_rescaled=exposure.rescale_intensity(hog_image,in_range=(0,2))

# %%
plt.figure()
plt.imshow(hog_image_rescaled,cmap='gray')
plt.title('HOG features')
# Out:
# Text(0.5, 1.0, 'HOG features')
