# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
img=mpimg.imread("image_lane_c.jpg")

# %%
img.shape
# Out:
# (540, 960, 3)

# %%
img_copy=np.copy(img)
img_copy.shape
# Out:
# (540, 960, 3)

# %%
img_copy[(img_copy[:,:,0]<200) |
         (img_copy[:,:,1]<200) |
         (img_copy[:,:,1]<200) ]=0

# %%
plt.imshow(img_copy,cmap='gray')
plt.show()
